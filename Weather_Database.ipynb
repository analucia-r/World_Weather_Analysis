# %%
###   Prepare Environment   
import requests  # needed for web crawls 
import pandas as pd # our Panda friend
import matplotlib.pyplot as plt # matplotlib for plotting
import numpy as np  # numpy for calculations
from citipy import citipy # Wendy Peng's amazing cities library
from datetime import datetime # working with dates
import time  # working with time

##  import our api keys
from config import weather_api_key  ## for weather data
from config import g_key ## for gmaps heatmaps

# %%
###  I.2. Generate a new set of 1,500 random latitude and longitude combinations.
#         Using NumPy random number generation with dictated lows, high and size of sample
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)  ## 
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs) ## packs both variables into a tupled zip file
lat_lngs # show me the zip file

# %%
##  I.2.a Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs) #write the zip file into a list, so you can work with it

# %%
###  I.3.Get the nearest city using the citipy module. 

## Create a list for holding the cities.
cities = []  # empty list

## Identify the nearest city for each latitude and longitude combination.
## The citipy module finds the nearest city to the latitude and longitude pair with a population of 500 or more.

for coordinate in coordinates:  # loop thru coordinates llist of 1500 lats and lngs
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    try:
    # If the city is unique, then we will add it to the cities list.
        if city not in cities:
            cities.append(city)
    except():
        print("General Error... skipping.")   
        # Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
### I.4-5.Perform an API Call with the OpenWeatherMap.
 
 ## I.4.a General a url for querying openweathermap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=616c594c4e39493991cf0dbaed852218

# %%
##  Prepare empty city list for processing the import

# start with an empty list for weather data
city_data=[]  # empty list

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1  # number of records in crawl
set_count = 1  # # of sets in crawl.  50 cities per set.

# Loop through all the cities in the list.
for i, city in enumerate(cities): # for loop with enumerate. reference index and city var

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50): ## if index divisble by 50 and index> 50, creates a new group
        set_count += 1  # adds one to set count 
        record_count = 1 # resets record count to 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        
        ## Challenge I.5 Weather Description
        city_weather_main=city_weather["weather"][0]["main"]   
        city_weather_desc = city_weather["weather"][0]["description"]
        
        ## Challenge I.5 try - Get inches of rain in last three hours where it has rained.
        try:
            if city_weather["weather"][0]["main"]=="Rain":
                city_rain_inches= city_weather["rain"]["3h"]
            else: 
                city_rain_inches=0
        except:  print (f"failing on the rain. skipping")
             
        ## Challenge I.5 try - except practice.  Now do with snow
        try:
            if city_weather["weather"][0]["main"]=="Snow":
                city_snow_inches= city_weather["snow"]["3h"]
            else: 
                city_snow_inches=0
        except:  print (f"failing on the snow. skipping")
              
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Overall Weather" : city_weather_main,
                          "Weather Description" : city_weather_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Rain Inches (last 3 hrs)" : city_rain_inches,
                          "Snow Inches (last 3 hrs)" : city_snow_inches
                          })
         
                         
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass  ## general purpose statement to handle all errors and continue

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nhulunbuy
# Processing Record 2 of Set 1 | dawei
# Processing Record 3 of Set 1 | saskylakh
# Processing Record 4 of Set 1 | rikitea
# failing on the rain. skipping
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | coihaique
# Processing Record 7 of Set 1 | narsaq
# Processing Record 8 of Set 1 | loubomo
# failing on the rain. skipping
# Processing Record 9 of Set 1 | komsomolskiy
# Processing Record 10 of Set 1 | itarema
# Processing Record 11 of Set 1 | xiamen
# Processing Record 12 of Set 1 | upernavik
# Processing Record 13 of Set 1 | beyneu
# Processing Record 14 of Set 1 | ternate
# Processing Record 15 of Set 1 | sao joao da barra
# Processing Record 16 of Set 1 | mar del plata
# Processing Record 17 of Set 1 | ushuaia
# failing on the rain. skipping
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | moroni
# Processing Record 23 of Set 1 | quelimane
# Processing Record 24 of Set 1 | codrington
# Processing Record 25 of Set 1 | sicuani
# Processing Record 26 of Set 1 | san patricio
# Processing Record 27 of Set 1 | hualmay
# Processing Record 28 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 1 | abu samrah
# Processing Record 30 of Set 1 | mount gambier
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | pisco
# Processing Record 33 of Set 1 | mehamn
# Processing Record 34 of Set 1 | havoysund
# failing on the snow. skipping
# Processing Record 35 of Set 1 | victoria
# Processing Record 36 of Set 1 | jizan
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | ixtapa
# Processing Record 40 of Set 1 | zhigansk
# Processing Record 41 of Set 1 | gigmoto
# Processing Record 42 of Set 1 | saldanha
# Processing Record 43 of Set 1 | zhenjiang
# Processing Record 44 of Set 1 | asyut
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | vieux-habitants
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | irtyshskiy
# Processing Record 49 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 1 | azimur
# City not found. Skipping...
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | saint george
# Processing Record 3 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 2 | coruripe
# Processing Record 5 of Set 2 | mahebourg
# Processing Record 6 of Set 2 | ocampo
# Processing Record 7 of Set 2 | puerto ayora
# failing on the rain. skipping
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | sivaki
# Processing Record 10 of Set 2 | la ronge
# Processing Record 11 of Set 2 | khani
# Processing Record 12 of Set 2 | caravelas
# Processing Record 13 of Set 2 | ponta do sol
# Processing Record 14 of Set 2 | ilulissat
# failing on the snow. skipping
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | mapiri
# Processing Record 17 of Set 2 | auki
# Processing Record 18 of Set 2 | itarantim
# Processing Record 19 of Set 2 | kudahuvadhoo
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | boca do acre
# Processing Record 22 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | tampa
# Processing Record 26 of Set 2 | necochea
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | lander
# Processing Record 29 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 30 of Set 2 | tral
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | olafsvik
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | chipinge
# Processing Record 35 of Set 2 | ust-kan
# Processing Record 36 of Set 2 | margate
# Processing Record 37 of Set 2 | senneterre
# failing on the snow. skipping
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | farafangana
# failing on the rain. skipping
# Processing Record 41 of Set 2 | vermillion
# Processing Record 42 of Set 2 | prata
# Processing Record 43 of Set 2 | sechura
# Processing Record 44 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 2 | tiksi
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | hobart
# Processing Record 48 of Set 2 | erenhot
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | khorixas
# Processing Record 1 of Set 3 | albany
# Processing Record 2 of Set 3 | cherskiy
# Processing Record 3 of Set 3 | pudem
# Processing Record 4 of Set 3 | ullapool
# Processing Record 5 of Set 3 | yablonovo
# Processing Record 6 of Set 3 | isangel
# Processing Record 7 of Set 3 | bethel
# Processing Record 8 of Set 3 | sola
# Processing Record 9 of Set 3 | port alfred
# failing on the rain. skipping
# Processing Record 10 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 3 | birjand
# Processing Record 12 of Set 3 | avarua
# Processing Record 13 of Set 3 | atoyac
# Processing Record 14 of Set 3 | brae
# Processing Record 15 of Set 3 | pitea
# Processing Record 16 of Set 3 | trelew
# Processing Record 17 of Set 3 | cidreira
# Processing Record 18 of Set 3 | port hedland
# Processing Record 19 of Set 3 | keti bandar
# Processing Record 20 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 22 of Set 3 | japura
# Processing Record 23 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 3 | aklavik
# Processing Record 25 of Set 3 | kodiak
# Processing Record 26 of Set 3 | dondo
# Processing Record 27 of Set 3 | waw
# Processing Record 28 of Set 3 | vardo
# Processing Record 29 of Set 3 | dingle
# Processing Record 30 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 3 | arrifes
# Processing Record 32 of Set 3 | bousso
# Processing Record 33 of Set 3 | qaqortoq
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | luderitz
# Processing Record 36 of Set 3 | iskateley
# Processing Record 37 of Set 3 | sisimiut
# Processing Record 38 of Set 3 | cape town
# Processing Record 39 of Set 3 | arlit
# Processing Record 40 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 3 | lavrentiya
# Processing Record 42 of Set 3 | palmer
# Processing Record 43 of Set 3 | lincoln
# Processing Record 44 of Set 3 | progreso
# Processing Record 45 of Set 3 | pevek
# Processing Record 46 of Set 3 | nanortalik
# Processing Record 47 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 3 | jacqueville
# failing on the rain. skipping
# Processing Record 49 of Set 3 | abrau-dyurso
# Processing Record 50 of Set 3 | mitsamiouli
# Processing Record 1 of Set 4 | husavik
# Processing Record 2 of Set 4 | azul
# Processing Record 3 of Set 4 | sibolga
# Processing Record 4 of Set 4 | castro
# Processing Record 5 of Set 4 | harlingen
# Processing Record 6 of Set 4 | georgetown
# Processing Record 7 of Set 4 | oum hadjer
# Processing Record 8 of Set 4 | harper
# failing on the rain. skipping
# Processing Record 9 of Set 4 | jackson
# Processing Record 10 of Set 4 | dzhuryn
# Processing Record 11 of Set 4 | portland
# Processing Record 12 of Set 4 | wanning
# Processing Record 13 of Set 4 | orel
# Processing Record 14 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 4 | krasnovishersk
# Processing Record 16 of Set 4 | shiyan
# Processing Record 17 of Set 4 | funtua
# Processing Record 18 of Set 4 | kismayo
# Processing Record 19 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 4 | guarapari
# Processing Record 22 of Set 4 | nikolayevka
# Processing Record 23 of Set 4 | souillac
# Processing Record 24 of Set 4 | salalah
# Processing Record 25 of Set 4 | koutsouras
# Processing Record 26 of Set 4 | mezen
# Processing Record 27 of Set 4 | coquimbo
# Processing Record 28 of Set 4 | jiazi
# Processing Record 29 of Set 4 | cuxhaven
# Processing Record 30 of Set 4 | bourail
# Processing Record 31 of Set 4 | vestmannaeyjar
# Processing Record 32 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 33 of Set 4 | fukue
# Processing Record 34 of Set 4 | xining
# Processing Record 35 of Set 4 | kinsale
# Processing Record 36 of Set 4 | marsh harbour
# Processing Record 37 of Set 4 | riyadh
# Processing Record 38 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 4 | nikolskoye
# Processing Record 40 of Set 4 | bettiah
# Processing Record 41 of Set 4 | lumut
# Processing Record 42 of Set 4 | redlands
# Processing Record 43 of Set 4 | qasigiannguit
# Processing Record 44 of Set 4 | severo-kurilsk
# Processing Record 45 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 4 | zabolotovka
# Processing Record 47 of Set 4 | shar
# Processing Record 48 of Set 4 | urumqi
# Processing Record 49 of Set 4 | shalakusha
# failing on the snow. skipping
# Processing Record 50 of Set 4 | kahului
# Processing Record 1 of Set 5 | chapais
# Processing Record 2 of Set 5 | chokurdakh
# failing on the snow. skipping
# Processing Record 3 of Set 5 | snezhnogorsk
# Processing Record 4 of Set 5 | ahipara
# Processing Record 5 of Set 5 | stavrovo
# Processing Record 6 of Set 5 | verkhnyaya sinyachikha
# Processing Record 7 of Set 5 | pierre
# Processing Record 8 of Set 5 | tucuman
# Processing Record 9 of Set 5 | puerto leguizamo
# Processing Record 10 of Set 5 | los llanos de aridane
# Processing Record 11 of Set 5 | guanica
# Processing Record 12 of Set 5 | boralday
# Processing Record 13 of Set 5 | eqbaliyeh
# Processing Record 14 of Set 5 | anshun
# Processing Record 15 of Set 5 | airai
# Processing Record 16 of Set 5 | seguela
# failing on the rain. skipping
# Processing Record 17 of Set 5 | toamasina
# Processing Record 18 of Set 5 | poum
# Processing Record 19 of Set 5 | fortuna
# Processing Record 20 of Set 5 | hov
# Processing Record 21 of Set 5 | christchurch
# Processing Record 22 of Set 5 | vila
# Processing Record 23 of Set 5 | mtsamboro
# Processing Record 24 of Set 5 | brigantine
# Processing Record 25 of Set 5 | luau
# Processing Record 26 of Set 5 | pangnirtung
# Processing Record 27 of Set 5 | karratha
# Processing Record 28 of Set 5 | nanded
# City not found. Skipping...
# Processing Record 29 of Set 5 | mersing
# Processing Record 30 of Set 5 | tias
# Processing Record 31 of Set 5 | port elizabeth
# Processing Record 32 of Set 5 | elizabeth city
# Processing Record 33 of Set 5 | manali
# Processing Record 34 of Set 5 | buraydah
# Processing Record 35 of Set 5 | bambanglipuro
# Processing Record 36 of Set 5 | bambous virieux
# failing on the rain. skipping
# Processing Record 37 of Set 5 | eyl
# Processing Record 38 of Set 5 | talnakh
# Processing Record 39 of Set 5 | watsa
# Processing Record 40 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 5 | khatanga
# Processing Record 42 of Set 5 | torbay
# Processing Record 43 of Set 5 | hithadhoo
# Processing Record 44 of Set 5 | sinjar
# Processing Record 45 of Set 5 | iqaluit
# failing on the snow. skipping
# Processing Record 46 of Set 5 | sohag
# Processing Record 47 of Set 5 | chuy
# Processing Record 48 of Set 5 | faanui
# Processing Record 49 of Set 5 | haines junction
# Processing Record 50 of Set 5 | namibe
# Processing Record 1 of Set 6 | tacuarembo
# Processing Record 2 of Set 6 | pulau sebang
# Processing Record 3 of Set 6 | bertoua
# Processing Record 4 of Set 6 | kobojango
# City not found. Skipping...
# Processing Record 5 of Set 6 | hami
# Processing Record 6 of Set 6 | bhabua
# Processing Record 7 of Set 6 | pringsewu
# Processing Record 8 of Set 6 | nantucket
# Processing Record 9 of Set 6 | korla
# Processing Record 10 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 6 | cedar city
# Processing Record 12 of Set 6 | gamba
# failing on the rain. skipping
# Processing Record 13 of Set 6 | thompson
# Processing Record 14 of Set 6 | hokitika
# Processing Record 15 of Set 6 | vung tau
# Processing Record 16 of Set 6 | dicabisagan
# Processing Record 17 of Set 6 | gouyave
# Processing Record 18 of Set 6 | kargasok
# Processing Record 19 of Set 6 | grand gaube
# Processing Record 20 of Set 6 | gilazi
# City not found. Skipping...
# Processing Record 21 of Set 6 | mangaratiba
# Processing Record 22 of Set 6 | vagur
# Processing Record 23 of Set 6 | rouvroy
# Processing Record 24 of Set 6 | kaitangata
# Processing Record 25 of Set 6 | grindavik
# Processing Record 26 of Set 6 | sioux lookout
# Processing Record 27 of Set 6 | vao
# Processing Record 28 of Set 6 | katsuura
# Processing Record 29 of Set 6 | cayenne
# Processing Record 30 of Set 6 | phetchabun
# Processing Record 31 of Set 6 | nikolayevsk-na-amure
# Processing Record 32 of Set 6 | mao
# failing on the rain. skipping
# Processing Record 33 of Set 6 | lalomanu
# City not found. Skipping...
# Processing Record 34 of Set 6 | pacific grove
# Processing Record 35 of Set 6 | kutum
# Processing Record 36 of Set 6 | san ramon
# Processing Record 37 of Set 6 | kenai
# Processing Record 38 of Set 6 | provideniya
# Processing Record 39 of Set 6 | noyabrsk
# failing on the snow. skipping
# Processing Record 40 of Set 6 | burnie
# Processing Record 41 of Set 6 | yulara
# Processing Record 42 of Set 6 | port lincoln
# Processing Record 43 of Set 6 | vallenar
# Processing Record 44 of Set 6 | aripuana
# Processing Record 45 of Set 6 | rosario
# Processing Record 46 of Set 6 | aguimes
# Processing Record 47 of Set 6 | ugoofaaru
# Processing Record 48 of Set 6 | svetlogorsk
# Processing Record 49 of Set 6 | cabedelo
# failing on the rain. skipping
# Processing Record 50 of Set 6 | luganville
# Processing Record 1 of Set 7 | tondano
# Processing Record 2 of Set 7 | catabola
# failing on the rain. skipping
# Processing Record 3 of Set 7 | roald
# Processing Record 4 of Set 7 | presidencia roque saenz pena
# Processing Record 5 of Set 7 | gonda
# Processing Record 6 of Set 7 | sao filipe
# Processing Record 7 of Set 7 | pangody
# Processing Record 8 of Set 7 | arraial do cabo
# Processing Record 9 of Set 7 | valparaiso
# Processing Record 10 of Set 7 | abu zabad
# Processing Record 11 of Set 7 | norman wells
# Processing Record 12 of Set 7 | banmo
# City not found. Skipping...
# Processing Record 13 of Set 7 | guane
# Processing Record 14 of Set 7 | komarikhinskiy
# Processing Record 15 of Set 7 | bathsheba
# Processing Record 16 of Set 7 | saint-denis
# Processing Record 17 of Set 7 | makakilo city
# Processing Record 18 of Set 7 | galle
# Processing Record 19 of Set 7 | filadelfia
# Processing Record 20 of Set 7 | horn
# Processing Record 21 of Set 7 | touros
# failing on the rain. skipping
# Processing Record 22 of Set 7 | vila do maio
# Processing Record 23 of Set 7 | raudeberg
# Processing Record 24 of Set 7 | tabuk
# Processing Record 25 of Set 7 | mokhsogollokh
# Processing Record 26 of Set 7 | canutama
# Processing Record 27 of Set 7 | jaciara
# failing on the rain. skipping
# Processing Record 28 of Set 7 | kleck
# City not found. Skipping...
# Processing Record 29 of Set 7 | okhotsk
# Processing Record 30 of Set 7 | luanda
# Processing Record 31 of Set 7 | suluq
# Processing Record 32 of Set 7 | faya
# Processing Record 33 of Set 7 | cabo san lucas
# Processing Record 34 of Set 7 | klaksvik
# Processing Record 35 of Set 7 | east london
# failing on the rain. skipping
# Processing Record 36 of Set 7 | praia
# Processing Record 37 of Set 7 | camana
# Processing Record 38 of Set 7 | price
# Processing Record 39 of Set 7 | bayshore gardens
# Processing Record 40 of Set 7 | llangefni
# Processing Record 41 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 42 of Set 7 | nivala
# failing on the snow. skipping
# Processing Record 43 of Set 7 | joshimath
# Processing Record 44 of Set 7 | pedernales
# Processing Record 45 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 7 | ambilobe
# failing on the rain. skipping
# Processing Record 47 of Set 7 | san isidro
# Processing Record 48 of Set 7 | esperance
# Processing Record 49 of Set 7 | barcelos
# Processing Record 50 of Set 7 | nome
# Processing Record 1 of Set 8 | khandyga
# Processing Record 2 of Set 8 | barzas
# failing on the snow. skipping
# Processing Record 3 of Set 8 | lanas
# Processing Record 4 of Set 8 | bend
# Processing Record 5 of Set 8 | alyangula
# Processing Record 6 of Set 8 | kurchum
# Processing Record 7 of Set 8 | victor harbor
# Processing Record 8 of Set 8 | atambua
# Processing Record 9 of Set 8 | mananjary
# failing on the rain. skipping
# Processing Record 10 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 8 | avera
# Processing Record 12 of Set 8 | te anau
# Processing Record 13 of Set 8 | college
# Processing Record 14 of Set 8 | yambio
# Processing Record 15 of Set 8 | neiafu
# Processing Record 16 of Set 8 | susangerd
# Processing Record 17 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 18 of Set 8 | yar-sale
# Processing Record 19 of Set 8 | port-cartier
# failing on the snow. skipping
# Processing Record 20 of Set 8 | kupino
# failing on the snow. skipping
# Processing Record 21 of Set 8 | talara
# Processing Record 22 of Set 8 | general roca
# Processing Record 23 of Set 8 | mustasaari
# Processing Record 24 of Set 8 | ngaoundere
# Processing Record 25 of Set 8 | carutapera
# Processing Record 26 of Set 8 | ouesso
# Processing Record 27 of Set 8 | bose
# Processing Record 28 of Set 8 | kushiro
# Processing Record 29 of Set 8 | erdenet
# Processing Record 30 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 31 of Set 8 | sibu
# Processing Record 32 of Set 8 | boa vista
# Processing Record 33 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 8 | fairbanks
# Processing Record 35 of Set 8 | gizo
# failing on the rain. skipping
# Processing Record 36 of Set 8 | filingue
# Processing Record 37 of Set 8 | carangola
# Processing Record 38 of Set 8 | ayia trias
# Processing Record 39 of Set 8 | bengkulu
# Processing Record 40 of Set 8 | vanimo
# Processing Record 41 of Set 8 | lensk
# Processing Record 42 of Set 8 | meulaboh
# Processing Record 43 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 8 | marga
# Processing Record 45 of Set 8 | longyearbyen
# Processing Record 46 of Set 8 | socorro
# Processing Record 47 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 8 | columbus
# Processing Record 49 of Set 8 | ardakan
# Processing Record 50 of Set 8 | kalmunai
# Processing Record 1 of Set 9 | concordia
# Processing Record 2 of Set 9 | saint-pierre
# Processing Record 3 of Set 9 | bilibino
# Processing Record 4 of Set 9 | ostrovnoy
# failing on the snow. skipping
# Processing Record 5 of Set 9 | san cristobal
# Processing Record 6 of Set 9 | nerchinskiy zavod
# Processing Record 7 of Set 9 | tessalit
# Processing Record 8 of Set 9 | pata
# Processing Record 9 of Set 9 | niederkassel
# Processing Record 10 of Set 9 | buluang
# Processing Record 11 of Set 9 | bom jesus
# Processing Record 12 of Set 9 | daska
# Processing Record 13 of Set 9 | monrovia
# failing on the rain. skipping
# Processing Record 14 of Set 9 | vidim
# Processing Record 15 of Set 9 | gouria
# Processing Record 16 of Set 9 | alice springs
# Processing Record 17 of Set 9 | mocuba
# Processing Record 18 of Set 9 | clifton springs
# Processing Record 19 of Set 9 | peterhead
# Processing Record 20 of Set 9 | coro
# Processing Record 21 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 22 of Set 9 | deep river
# Processing Record 23 of Set 9 | shache
# Processing Record 24 of Set 9 | yunhe
# Processing Record 25 of Set 9 | san juan evangelista
# Processing Record 26 of Set 9 | flinders
# failing on the rain. skipping
# Processing Record 27 of Set 9 | warrnambool
# Processing Record 28 of Set 9 | porbandar
# Processing Record 29 of Set 9 | tolentino
# Processing Record 30 of Set 9 | shingu
# failing on the rain. skipping
# Processing Record 31 of Set 9 | grimstad
# Processing Record 32 of Set 9 | edgewater
# Processing Record 33 of Set 9 | balakhta
# Processing Record 34 of Set 9 | sebinkarahisar
# Processing Record 35 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 36 of Set 9 | cravo norte
# Processing Record 37 of Set 9 | fort saint james
# Processing Record 38 of Set 9 | yungkang
# City not found. Skipping...
# Processing Record 39 of Set 9 | puno
# Processing Record 40 of Set 9 | menongue
# Processing Record 41 of Set 9 | port augusta
# Processing Record 42 of Set 9 | ciras
# City not found. Skipping...
# Processing Record 43 of Set 9 | ontario
# Processing Record 44 of Set 9 | ancud
# Processing Record 45 of Set 9 | turayf
# Processing Record 46 of Set 9 | vila velha
# Processing Record 47 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 48 of Set 9 | san quintin
# Processing Record 49 of Set 9 | hamilton
# Processing Record 50 of Set 9 | agadir
# Processing Record 1 of Set 10 | asau
# Processing Record 2 of Set 10 | geraldton
# failing on the rain. skipping
# Processing Record 3 of Set 10 | sept-iles
# failing on the snow. skipping
# Processing Record 4 of Set 10 | lorengau
# Processing Record 5 of Set 10 | lagoa
# Processing Record 6 of Set 10 | ca mau
# Processing Record 7 of Set 10 | pathein
# Processing Record 8 of Set 10 | zhigalovo
# failing on the snow. skipping
# Processing Record 9 of Set 10 | veraval
# Processing Record 10 of Set 10 | encruzilhada do sul
# Processing Record 11 of Set 10 | alta floresta
# Processing Record 12 of Set 10 | batticaloa
# Processing Record 13 of Set 10 | hvide sande
# Processing Record 14 of Set 10 | kaifeng
# Processing Record 15 of Set 10 | bulgan
# Processing Record 16 of Set 10 | tocopilla
# Processing Record 17 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 10 | ferreira do alentejo
# Processing Record 19 of Set 10 | at-bashi
# Processing Record 20 of Set 10 | silver city
# Processing Record 21 of Set 10 | grand-lahou
# Processing Record 22 of Set 10 | ambon
# Processing Record 23 of Set 10 | namie
# failing on the rain. skipping
# Processing Record 24 of Set 10 | cockburn town
# Processing Record 25 of Set 10 | voh
# Processing Record 26 of Set 10 | lashio
# Processing Record 27 of Set 10 | thunder bay
# Processing Record 28 of Set 10 | williamsburg
# Processing Record 29 of Set 10 | awjilah
# Processing Record 30 of Set 10 | sapele
# Processing Record 31 of Set 10 | jurado
# Processing Record 32 of Set 10 | senador jose porfirio
# Processing Record 33 of Set 10 | qingdao
# Processing Record 34 of Set 10 | aitape
# Processing Record 35 of Set 10 | luangwa
# Processing Record 36 of Set 10 | luena
# Processing Record 37 of Set 10 | kampot
# Processing Record 38 of Set 10 | buala
# failing on the rain. skipping
# Processing Record 39 of Set 10 | ust-ishim
# Processing Record 40 of Set 10 | tricase
# Processing Record 41 of Set 10 | aswan
# Processing Record 42 of Set 10 | hasaki
# failing on the rain. skipping
# Processing Record 43 of Set 10 | northam
# Processing Record 44 of Set 10 | beaverlodge
# Processing Record 45 of Set 10 | hrinova
# Processing Record 46 of Set 10 | lingao
# Processing Record 47 of Set 10 | zyryanka
# Processing Record 48 of Set 10 | maningrida
# Processing Record 49 of Set 10 | marsaxlokk
# Processing Record 50 of Set 10 | bac lieu
# Processing Record 1 of Set 11 | banjar
# Processing Record 2 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 11 | gat
# Processing Record 4 of Set 11 | krasnorechenskiy
# failing on the snow. skipping
# Processing Record 5 of Set 11 | bandarbeyla
# Processing Record 6 of Set 11 | leningradskiy
# Processing Record 7 of Set 11 | phichit
# Processing Record 8 of Set 11 | along
# Processing Record 9 of Set 11 | kieta
# failing on the rain. skipping
# Processing Record 10 of Set 11 | myitkyina
# Processing Record 11 of Set 11 | namatanai
# failing on the rain. skipping
# Processing Record 12 of Set 11 | honningsvag
# Processing Record 13 of Set 11 | shalya
# Processing Record 14 of Set 11 | susah
# City not found. Skipping...
# Processing Record 15 of Set 11 | taoudenni
# Processing Record 16 of Set 11 | ust-kut
# Processing Record 17 of Set 11 | nurota
# Processing Record 18 of Set 11 | khromtau
# Processing Record 19 of Set 11 | bukama
# failing on the rain. skipping
# Processing Record 20 of Set 11 | bontang
# Processing Record 21 of Set 11 | humberto de campos
# Processing Record 22 of Set 11 | huarmey
# Processing Record 23 of Set 11 | rauma
# failing on the rain. skipping
# Processing Record 24 of Set 11 | longuenesse
# Processing Record 25 of Set 11 | tuatapere
# Processing Record 26 of Set 11 | kununurra
# Processing Record 27 of Set 11 | gzhatsk
# City not found. Skipping...
# Processing Record 28 of Set 11 | shuyskoye
# failing on the snow. skipping
# Processing Record 29 of Set 11 | port macquarie
# failing on the rain. skipping
# Processing Record 30 of Set 11 | dunedin
# Processing Record 31 of Set 11 | kaka
# Processing Record 32 of Set 11 | tomatlan
# Processing Record 33 of Set 11 | maniitsoq
# Processing Record 34 of Set 11 | san nicolas
# Processing Record 35 of Set 11 | batagay-alyta
# Processing Record 36 of Set 11 | digha
# Processing Record 37 of Set 11 | straumen
# failing on the rain. skipping
# Processing Record 38 of Set 11 | belomorsk
# failing on the snow. skipping
# Processing Record 39 of Set 11 | colares
# Processing Record 40 of Set 11 | kichera
# Processing Record 41 of Set 11 | salinopolis
# failing on the rain. skipping
# Processing Record 42 of Set 11 | berdigestyakh
# Processing Record 43 of Set 11 | kavaratti
# Processing Record 44 of Set 11 | vila franca do campo
# Processing Record 45 of Set 11 | novobureyskiy
# Processing Record 46 of Set 11 | ranong
# Processing Record 47 of Set 11 | kasongo
# Processing Record 48 of Set 11 | canyon
# Processing Record 49 of Set 11 | urdoma
# Processing Record 50 of Set 11 | fuerte olimpo
# Processing Record 1 of Set 12 | toulepleu
# City not found. Skipping...
# Processing Record 2 of Set 12 | yilan
# failing on the rain. skipping
# Processing Record 3 of Set 12 | asfi
# Processing Record 4 of Set 12 | kasongo-lunda
# failing on the rain. skipping
# Processing Record 5 of Set 12 | montepuez
# Processing Record 6 of Set 12 | skjervoy
# failing on the snow. skipping
# Processing Record 7 of Set 12 | vargem grande
# failing on the rain. skipping
# Processing Record 8 of Set 12 | cururupu
# Processing Record 9 of Set 12 | sarakhs
# Processing Record 10 of Set 12 | srednekolymsk
# failing on the snow. skipping
# Processing Record 11 of Set 12 | mizpe ramon
# City not found. Skipping...
# Processing Record 12 of Set 12 | biltine
# Processing Record 13 of Set 12 | nemuro
# failing on the rain. skipping
# Processing Record 14 of Set 12 | ryotsu
# failing on the rain. skipping
# Processing Record 15 of Set 12 | mount isa
# Processing Record 16 of Set 12 | komarichi
# Processing Record 17 of Set 12 | rio verde de mato grosso
# Processing Record 18 of Set 12 | erie
# Processing Record 19 of Set 12 | atar
# Processing Record 20 of Set 12 | hambantota
# Processing Record 21 of Set 12 | saquarema
# Processing Record 22 of Set 12 | clearwater
# Processing Record 23 of Set 12 | mountain home
# Processing Record 24 of Set 12 | guekedou
# City not found. Skipping...
# Processing Record 25 of Set 12 | hinganghat
# Processing Record 26 of Set 12 | almaznyy
# Processing Record 27 of Set 12 | slantsy
# Processing Record 28 of Set 12 | balrampur
# Processing Record 29 of Set 12 | zaliznychne
# Processing Record 30 of Set 12 | ozark
# Processing Record 31 of Set 12 | cartagena del chaira
# Processing Record 32 of Set 12 | turkistan
# failing on the rain. skipping
# Processing Record 33 of Set 12 | jarjis
# City not found. Skipping...
# Processing Record 34 of Set 12 | iwade
# failing on the rain. skipping
# Processing Record 35 of Set 12 | ajdabiya
# Processing Record 36 of Set 12 | bereda
# Processing Record 37 of Set 12 | junin
# Processing Record 38 of Set 12 | pudozh
# failing on the snow. skipping
# Processing Record 39 of Set 12 | henties bay
# Processing Record 40 of Set 12 | lidkoping
# Processing Record 41 of Set 12 | gaoua
# Processing Record 42 of Set 12 | wajir
# Processing Record 43 of Set 12 | novyy urengoy
# failing on the snow. skipping
# Processing Record 44 of Set 12 | nouakchott
# Processing Record 45 of Set 12 | bay roberts
# Processing Record 46 of Set 12 | chiplun
# Processing Record 47 of Set 12 | hofn
# Processing Record 48 of Set 12 | warragul
# Processing Record 49 of Set 12 | aberdeen
# Processing Record 50 of Set 12 | kavieng
# Processing Record 1 of Set 13 | guymon
# Processing Record 2 of Set 13 | murray bridge
# Processing Record 3 of Set 13 | adrar
# Processing Record 4 of Set 13 | kloulklubed
# Processing Record 5 of Set 13 | cascais
# Processing Record 6 of Set 13 | jibuti
# Processing Record 7 of Set 13 | bad doberan
# Processing Record 8 of Set 13 | broome
# failing on the rain. skipping
# Processing Record 9 of Set 13 | sinnamary
# Processing Record 10 of Set 13 | mvuma
# failing on the rain. skipping
# Processing Record 11 of Set 13 | tefe
# failing on the rain. skipping
# Processing Record 12 of Set 13 | san juan
# Processing Record 13 of Set 13 | hobyo
# failing on the rain. skipping
# Processing Record 14 of Set 13 | tambopata
# failing on the rain. skipping
# Processing Record 15 of Set 13 | boyolangu
# Processing Record 16 of Set 13 | abong mbang
# Processing Record 17 of Set 13 | anori
# Processing Record 18 of Set 13 | butoiesti
# Processing Record 19 of Set 13 | praia da vitoria
# Processing Record 20 of Set 13 | san jeronimo
# Processing Record 21 of Set 13 | thano bula khan
# City not found. Skipping...
# Processing Record 22 of Set 13 | tongzi
# Processing Record 23 of Set 13 | petrivka
# Processing Record 24 of Set 13 | totness
# Processing Record 25 of Set 13 | maltahohe
# Processing Record 26 of Set 13 | belmonte
# Processing Record 27 of Set 13 | kysyl-syr
# Processing Record 28 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 13 | anchorage
# Processing Record 30 of Set 13 | ust-barguzin
# Processing Record 31 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 13 | taldan
# Processing Record 33 of Set 13 | sandwick
# Processing Record 34 of Set 13 | ballina
# Processing Record 35 of Set 13 | burley
# Processing Record 36 of Set 13 | playa vicente
# Processing Record 37 of Set 13 | kaeo
# Processing Record 38 of Set 13 | mama
# Processing Record 39 of Set 13 | umm lajj
# Processing Record 40 of Set 13 | barreirinhas
# failing on the rain. skipping
# Processing Record 41 of Set 13 | jerusalem
# Processing Record 42 of Set 13 | labuhan
# Processing Record 43 of Set 13 | san joaquin
# Processing Record 44 of Set 13 | meylan
# Processing Record 45 of Set 13 | kanniyakumari
# Processing Record 46 of Set 13 | jiwani
# Processing Record 47 of Set 13 | williams lake
# Processing Record 48 of Set 13 | lompoc
# Processing Record 49 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 13 | marion
# Processing Record 1 of Set 14 | olinda
# Processing Record 2 of Set 14 | tuy hoa
# Processing Record 3 of Set 14 | amalapuram
# Processing Record 4 of Set 14 | kirakira
# Processing Record 5 of Set 14 | opuwo
# Processing Record 6 of Set 14 | chumphon
# Processing Record 7 of Set 14 | juneau
# failing on the snow. skipping
# Processing Record 8 of Set 14 | kosh-agach
# Processing Record 9 of Set 14 | amapa
# Processing Record 10 of Set 14 | kamenka
# Processing Record 11 of Set 14 | gazli
# Processing Record 12 of Set 14 | barra do garcas
# Processing Record 13 of Set 14 | novobiryusinskiy
# Processing Record 14 of Set 14 | high level
# Processing Record 15 of Set 14 | beloha
# Processing Record 16 of Set 14 | port keats
# failing on the rain. skipping
# Processing Record 17 of Set 14 | lasa
# Processing Record 18 of Set 14 | kuah
# Processing Record 19 of Set 14 | matara
# Processing Record 20 of Set 14 | mancio lima
# failing on the rain. skipping
# Processing Record 21 of Set 14 | tabas
# Processing Record 22 of Set 14 | constitucion
# Processing Record 23 of Set 14 | tokur
# Processing Record 24 of Set 14 | galveston
# Processing Record 25 of Set 14 | inhambane
# failing on the rain. skipping
# Processing Record 26 of Set 14 | lazaro cardenas
# Processing Record 27 of Set 14 | banda aceh
# Processing Record 28 of Set 14 | manokwari
# failing on the rain. skipping
# Processing Record 29 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 30 of Set 14 | marzuq
# Processing Record 31 of Set 14 | riberalta
# Processing Record 32 of Set 14 | champerico
# Processing Record 33 of Set 14 | kapit
# Processing Record 34 of Set 14 | wladyslawowo
# Processing Record 35 of Set 14 | muhos
# failing on the snow. skipping
# Processing Record 36 of Set 14 | kuusamo
# Processing Record 37 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 14 | sterling
# Processing Record 39 of Set 14 | salto
# Processing Record 40 of Set 14 | moose factory
# Processing Record 41 of Set 14 | kiruna
# failing on the snow. skipping
# Processing Record 42 of Set 14 | abeche
# Processing Record 43 of Set 14 | samarai
# Processing Record 44 of Set 14 | glenwood springs
# Processing Record 45 of Set 14 | kupang
# Processing Record 46 of Set 14 | oistins
# Processing Record 47 of Set 14 | padang
# Processing Record 48 of Set 14 | hammerfest
# failing on the snow. skipping
# Processing Record 49 of Set 14 | alofi
# Processing Record 50 of Set 14 | nago
# Processing Record 1 of Set 15 | ushtobe
# Processing Record 2 of Set 15 | singaraja
# Processing Record 3 of Set 15 | maralal
# failing on the rain. skipping
# Processing Record 4 of Set 15 | quilmana
# Processing Record 5 of Set 15 | turtas
# Processing Record 6 of Set 15 | ust-nera
# Processing Record 7 of Set 15 | langsa
# Processing Record 8 of Set 15 | virginia beach
# Processing Record 9 of Set 15 | hanna
# Processing Record 10 of Set 15 | puerto rico
# Processing Record 11 of Set 15 | astipalaia
# City not found. Skipping...
# Processing Record 12 of Set 15 | liuzhou
# Processing Record 13 of Set 15 | honiara
# Processing Record 14 of Set 15 | ayan
# Processing Record 15 of Set 15 | la primavera
# Processing Record 16 of Set 15 | sinfra
# failing on the rain. skipping
# Processing Record 17 of Set 15 | ibicarai
# Processing Record 18 of Set 15 | bibiani
# failing on the rain. skipping
# Processing Record 19 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 15 | manuk mangkaw
# Processing Record 21 of Set 15 | markova
# Processing Record 22 of Set 15 | nganjuk
# failing on the rain. skipping
# Processing Record 23 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 24 of Set 15 | paamiut
# Processing Record 25 of Set 15 | yakeshi
# Processing Record 26 of Set 15 | san fernando
# Processing Record 27 of Set 15 | pombas
# Processing Record 28 of Set 15 | bani walid
# Processing Record 29 of Set 15 | ekhabi
# Processing Record 30 of Set 15 | xichang
# Processing Record 31 of Set 15 | khudumelapye
# Processing Record 32 of Set 15 | pingliang
# Processing Record 33 of Set 15 | amahai
# Processing Record 34 of Set 15 | ketchenery
# City not found. Skipping...
# Processing Record 35 of Set 15 | acarau
# Processing Record 36 of Set 15 | dong hoi
# Processing Record 37 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 15 | lervik
# Processing Record 39 of Set 15 | el roble
# Processing Record 40 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 15 | jacareacanga
# Processing Record 42 of Set 15 | opobo
# City not found. Skipping...
# Processing Record 43 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 44 of Set 15 | golden
# Processing Record 45 of Set 15 | alabaster
# Processing Record 46 of Set 15 | krasnoselkup
# failing on the snow. skipping
# Processing Record 47 of Set 15 | tahe
# Processing Record 48 of Set 15 | beringovskiy
# Processing Record 49 of Set 15 | puerto quijarro
# Processing Record 50 of Set 15 | butia
# Processing Record 1 of Set 16 | riachao das neves
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
### I.6 Add the collected data to a new dataframe.
city_data_df=pd.DataFrame(city_data)
city_data_df.head(5)
#city_data
# Out:
#           City Country                 Date      Lat       Lng  \
# 0    Nhulunbuy      AU  2022-03-26 00:22:34 -12.2333  136.7667
# 1        Dawei      MM  2022-03-26 00:22:34  14.0833   98.2000
# 2    Saskylakh      RU  2022-03-26 00:22:35  71.9167  114.0833
# 3      Rikitea      PF  2022-03-26 00:21:39 -23.1203 -134.9692
# 4  Yellowknife      CA  2022-03-26 00:20:51  62.4560 -114.3525
#
#   Overall Weather Weather Description  Max Temp  Humidity  Cloudiness  \
# 0          Clouds     overcast clouds     83.01        74         100
# 1           Clear           clear sky     76.84        89           5
# 2          Clouds     overcast clouds    -17.93       100         100
# 3            Rain          light rain     79.68        73          20
# 4           Clear           clear sky     -1.59        51           0
#
#    Wind Speed  Rain Inches (last 3 hrs)  Snow Inches (last 3 hrs)
# 0       11.50                         0                         0
# 1        3.22                         0                         0
# 2        1.99                         0                         0
# 3       17.25                         0                         0
# 4        6.91                         0                         0

# %%
### I.7  Output the content to a CSV file so we have static data to work with...
output_data_file = "weather_data/weatherPy_challenge.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
## I.9.a Using Pandas: How many cities have recorded rainfall
city_data_df[city_data_df["Rain Inches (last 3 hrs)"] > 0 ].count()
# Returns 72 Cities with a Rain count
# Out:
# City                        0
# Country                     0
# Date                        0
# Lat                         0
# Lng                         0
# Overall Weather             0
# Weather Description         0
# Max Temp                    0
# Humidity                    0
# Cloudiness                  0
# Wind Speed                  0
# Rain Inches (last 3 hrs)    0
# Snow Inches (last 3 hrs)    0
# dtype: int64

# %%
## I.9.b Using Pandas: How many cities have recorded snowfall
city_data_df[city_data_df["Snow Inches (last 3 hrs)"] > 0 ].count()
# Returns 23 Cities with a Snow count
# Out:
# City                        0
# Country                     0
# Date                        0
# Lat                         0
# Lng                         0
# Overall Weather             0
# Weather Description         0
# Max Temp                    0
# Humidity                    0
# Cloudiness                  0
# Wind Speed                  0
# Rain Inches (last 3 hrs)    0
# Snow Inches (last 3 hrs)    0
# dtype: int64
